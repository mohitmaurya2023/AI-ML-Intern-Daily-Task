# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread("image.jpeg")

# %%
plt.imshow(img)

# %%
img.size
# Out:
# 2544009

# %%
img.shape
# Out:
# (559, 1517, 3)

# %%
559*1517*3
# Out:
# 2544009

# %%
a = img[50,50]

# %%
plt.imshow(img)

# %%
a
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
img1 = cv2.imread("image.jpeg")

# %%
b,g,r = cv2.split(img1)

# %%
b
# Out:
# array([[ 31,  31,  31, ...,  31,  31,  31],
#        [ 31,  33,  57, ...,  57,  33,  31],
#        [ 31,  57, 255, ..., 255,  57,  31],
#        ...,
#        [ 31,  57, 255, ..., 255,  57,  31],
#        [ 31,  33,  57, ...,  57,  33,  31],
#        [ 31,  31,  31, ...,  31,  31,  31]], dtype=uint8)

# %%
b.shape
# Out:
# (559, 1517)

# %%
g.shape
# Out:
# (559, 1517)

# %%
r.shape
# Out:
# (559, 1517)

# %%
plt.imshow(img1)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_rgb1 = cv2.resize(img_rgb, (840, 980))
plt.imshow(img_rgb1)

# %%
img_f1 = cv2.flip(img_rgb, 0)
plt.imshow(img_f1)

# %%
imgf1 = cv2.flip(img_rgb, 1)
plt.imshow(imgf1)

# %%
img_rgb.shape
# Out:
# (559, 1517, 3)

# %%
#ROI = Region of interest
x_offset= 388-100
y_offset= 290-100

# %%
rows, cols, channels = img_rgb.shape

# %%
roi = img_rgb[100:200, 100:200]
plt.imshow(roi)

# %%
roi = img_rgb[0:x_offset, 0:y_offset]
plt.imshow(roi)

# %%
roi = img_rgb[x_offset:rows, y_offset:cols]
plt.imshow(roi)

# %%
roi = img_rgb[0:rows, 0:cols]
plt.imshow(roi)

# %%
roi1 = img_rgb[100:200, 100:200]
plt.imshow(roi1)

# %%
roi2 = img_rgb[200:300, 200:400]
plt.imshow(roi2)

# %%
img_rgb.shape
# Out:
# (559, 1517, 3)

# %%
f=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img_rgb, text='Nashit Sir Class', org=(100,100), fontFace=f, fontScale=2,color=(100,250,230), thickness=3)
plt.imshow(img_rgb)

# %%
# img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB)
# plt.imshow(img_gray )
img_grey = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(img_grey, cmap = 'gray' )

# %%
img2 = cv2.imread("image.jpeg")

# %%
plt.imshow(img2)

# %%
img3 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
import cv2
img_g = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img_g, cmap = 'gray')

# %%
img_inv = cv2.bitwise_not(img_g)
plt.imshow(img_inv, cmap='gray')

# %%
img_sm = cv2.GaussianBlur(img_inv, (25, 25), sigmaX=0, sigmaY=0)
plt.imshow(img_sm, cmap = 'gray')

# %%
img_pencil = cv2.divide(img_g, 255-img_sm, scale = 255)
plt.imshow(img_pencil, cmap='gray')

# %%
import numpy as np

# %%
plt.imshow(img1)

# %%
face_cas = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
def detect_face(image):
    face_img = image.copy()
    face_cont = face_cas.detectMultiScale(face_img)

    for(x,y, w,h) in face_cont:
        cv2.rectangle(face_img, (x,y), (x+w, y+h), (255, 255, 255), 4)

    return face_img

# %%
res = detect_face(img1)
plt.imshow(res, cmap='gray')

# %%
img_sunny = cv2.imread('sunny.png')

# %%
plt.imshow(img_sunny)

# %%
res = detect_face(img_sunny)
plt.imshow(res, cmap='gray')
